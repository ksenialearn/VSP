# %% [markdown]
# #### Vision Service Plan (VSP) – Vision and Eye Health Surveillance 2016.
#
# This dataset is a de-identified summary table of vision and eye health data indicators from VSP, stratified by all available combinations of age group, race/ethnicity, gender, and state. VSP claims for VEHSS provides a convenience sample of vision insurance members representing approximately more than 1 in 4 of the U.S. population.
#
# Data source: https://chronicdata.cdc.gov/Vision-Eye-Health/Vision-Service-Plan-VSP-Vision-and-Eye-Health-Surv/

# %% [markdown]
# #### The goal of this project is to derive any interesting insights about the vision exams in US

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
#Read in VSP dataset
vsp_full = pd.read_csv('VSP.csv', low_memory=False)

# %%
#Dimensions
vsp_full.shape
# Out:
# (63706, 33)

# %%
vsp_full.head(2)
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc DataSource  \
# 0       2016     2016           AK       Alaska        VSP
# 1       2016     2016           AK       Alaska        VSP
#
#                  Topic   Category  \
# 0  Service Utilization  Eye exams
# 1  Service Utilization  Eye exams
#
#                                             Question  \
# 0  Proportion of patients who had an eye exam in ...
# 1  Proportion of patients who had an eye exam in ...
#
#                                     Response         Age  \
# 0  By an ophthalmologists or other physician  0-17 years
# 1  By an ophthalmologists or other physician  0-17 years
#
#            ...                                        GeoLocation TopicID  \
# 0          ...           (64.84507995700051, -147.72205903599973)    TUTL
# 1          ...           (64.84507995700051, -147.72205903599973)    TUTL
#
#   CategoryID QuestionID ResponseID   AgeID  GenderID RaceEthnicityID  \
# 0     CUTLEX     QUTLEX     REXPHS  AGE017        GF         ALLRACE
# 1     CUTLEX     QUTLEX     REXPHS  AGE017        GM         ALLRACE
#
#   RiskFactorID  RiskFactorResponseID
# 0        RFALL                 RFTOT
# 1        RFALL                 RFTOT
#
# [2 rows x 33 columns]

# %%
#Check columns and their data types
vsp_full.dtypes
# Out:
# YearStart                       int64
# YearEnd                         int64
# LocationAbbr                   object
# LocationDesc                   object
# DataSource                     object
# Topic                          object
# Category                       object
# Question                       object
# Response                       object
# Age                            object
# Gender                         object
# RaceEthnicity                  object
# RiskFactor                     object
# RiskFactorResponse             object
# Data_Value_Unit                object
# Data_Value_Type                object
# Data_Value                    float64
# Data_Value_Footnote_Symbol     object
# Data_Value_Footnote            object
# Low_Confidence_limit          float64
# High_Confidence_Limit         float64
# Sample_Size                   float64
# LocationID                      int64
# GeoLocation                    object
# TopicID                        object
# CategoryID                     object
# QuestionID                     object
# ResponseID                     object
# AgeID                          object
# GenderID                       object
# RaceEthnicityID                object
# RiskFactorID                   object
# RiskFactorResponseID           object
# dtype: object

# %%
#Drop columns that are all nulls
vsp_is_null = vsp_full.isnull().all()
null_cols = vsp_is_null[vsp_is_null.values].index
working_data = vsp_full.drop(null_cols, axis=1)
print('Dropped columns with all nulls: ', null_cols.values)
# Out:
# Dropped columns with all nulls:  ['Sample_Size']

# %%
#Separate categorical and numerical values
categorical = working_data.select_dtypes(include = ['object'])
numeric = working_data.select_dtypes(exclude = ['object'])

# %%
#Check categorical variables
for column in categorical:
    print('------------------')
    print('Variable: ', column)
    print(categorical[column].value_counts())
# Out:
# ------------------
# Variable:  LocationAbbr
# US    1668
# CA    1638
# MI    1527
# OH    1484
# IN    1448
# NY    1400
# OR    1390
# TX    1389
# WA    1368
# CO    1347
# IL    1345
# VA    1328
# FL    1324
# AZ    1308
# NC    1297
# MO    1295
# NV    1256
# OK    1255
# GA    1249
# HI    1243
# NJ    1237
# ID    1232
# KS    1219
# WV    1217
# NM    1213
# AL    1208
# MT    1203
# WI    1198
# MA    1195
# SC    1195
# MN    1191
# LA    1190
# MS    1188
# IA    1182
# TN    1174
# NE    1165
# MD    1155
# KY    1141
# PA    1137
# CT    1128
# UT    1105
# VT    1087
# WY    1079
# NH    1064
# SD    1063
# AK    1044
# AR    1029
# RI    1021
# DE    1004
# ME     941
# ND     940
# DC     645
# PR     223
# GU     118
# MH       8
# VI       8
# Name: LocationAbbr, dtype: int64
# ------------------
# Variable:  LocationDesc
# National                1668
# California              1638
# Michigan                1527
# Ohio                    1484
# Indiana                 1448
# New York                1400
# Oregon                  1390
# Texas                   1389
# Washington              1368
# Colorado                1347
# Illinois                1345
# Virginia                1328
# Florida                 1324
# Arizona                 1308
# North Carolina          1297
# Missouri                1295
# Nevada                  1256
# Oklahoma                1255
# Georgia                 1249
# Hawaii                  1243
# New Jersey              1237
# Idaho                   1232
# Kansas                  1219
# West Virginia           1217
# New Mexico              1213
# Alabama                 1208
# Montana                 1203
# Wisconsin               1198
# Massachusetts           1195
# South Carolina          1195
# Minnesota               1191
# Louisiana               1190
# Mississippi             1188
# Iowa                    1182
# Tennessee               1174
# Nebraska                1165
# Maryland                1155
# Kentucky                1141
# Pennsylvania            1137
# Connecticut             1128
# Utah                    1105
# Vermont                 1087
# Wyoming                 1079
# New Hampshire           1064
# South Dakota            1063
# Alaska                  1044
# Arkansas                1029
# Rhode Island            1021
# Delaware                1004
# Maine                    941
# North Dakota             940
# District of Columbia     645
# Puerto Rico              223
# Guam                     118
# U.S. Virgin Islands        8
# Marshall Islands           8
# Name: LocationDesc, dtype: int64
# ------------------
# Variable:  DataSource
# VSP    63706
# Name: DataSource, dtype: int64
# ------------------
# Variable:  Topic
# Medical Diagnoses      60849
# Service Utilization     2857
# Name: Topic, dtype: int64
# ------------------
# Variable:  Category
# Other retinal disorders                                6138
# Disorders of refraction and accommodation              5635
# Glaucoma                                               5583
# Cataracts                                              5504
# Infectious and inflammatory diseases                   5447
# Orbital and external disease                           4802
# Diabetic eye diseases                                  3907
# Other visual disturbances                              3776
# Age related macular degeneration                       3573
# Cornea disorders                                       3136
# Blindness and low vision                               3018
# Eye exams                                              2857
# Strabismus and amblyopia                               2558
# Injury, burns and surgical complications of the eye    2271
# Cancer and neoplasms of the eye                        2050
# Disorders of optic nerve and visual pathways           1761
# Other eye disorders                                     895
# Retinal detachment and defects                          795
# Name: Category, dtype: int64
# ------------------
# Variable:  Question
# Annual prevalence of treated other retinal disorders                                6138
# Annual prevalence of treated disorders of refraction and accommodation              5635
# Annual prevalence of treated glaucoma                                               5583
# Annual prevalence of treated cataracts                                              5504
# Annual prevalence of treated infectious and inflammatory diseases                   5447
# Annual prevalence of treated orbital and external disease                           4802
# Annual prevalence of treated diabetic eye diseases                                  3907
# Annual prevalence of treated other visual disturbances                              3776
# Annual prevalence of treated age related macular degeneration                       3573
# Annual prevalence of treated cornea disorders                                       3136
# Annual prevalence of treated blindness and low vision                               3018
# Proportion of patients who had an eye exam in selected year                         2857
# Annual prevalence of treated strabismus and amblyopia                               2558
# Annual prevalence of treated injury, burns and surgical complications of the eye    2271
# Annual prevalence of treated eye cancer and neoplasms                               2050
# Annual prevalence of treated disorders of optic nerve and visual pathways           1761
# Annual prevalence of treated other eye disorders                                     895
# Annual prevalence of treated retinal detachment and defects                          795
# Name: Question, dtype: int64
# ------------------
# Variable:  Response
# Eyelid disorders                                          1723
# All Refraction and accommodation disorders                 970
# Myopia                                                     967
# By any provider type                                       963
# By an optometrist or optician                              963
# Astigmatism                                                961
# Hypermetropia                                              959
# Presbyopia                                                 956
# All Cataracts                                              941
# By an ophthalmologists or other physician                  931
# All Glaucoma                                               925
# All Orbital and external disease                           922
# Senile cataract                                            921
# Dry eye syndrome                                           912
# All Infectious and inflammatory diseases                   910
# All Other retinal disorders                                897
# All Other eye disorders                                    895
# Glaucoma suspect                                           891
# Other/unspecified other retinal disorders                  886
# All Cornea disorders                                       877
# All Strabismus and amblyopia                               875
# Conjunctivitis                                             867
# Pseudophakia                                               866
# All Age-related macular degeneration (AMD)                 864
# Strabismus                                                 863
# Keratitis                                                  857
# All Other visual disturbances                              857
# Other corneal disorders                                    857
# All Cancer and neoplasms of the eye diseases               843
# Benign neoplasm                                            843
#                                                           ...
# Vision impairment one eye                                  624
# Surgical complication of the eye                           613
# Open-angle glaucoma                                        579
# Moderate/Severe non-proliferative diabetic retinopathy     573
# Color blindness                                            542
# Wet-form age-related macular degeneration                  520
# Low-tension glaucoma                                       502
# Branch retinal vein occlusion                              482
# Proliferative diabetic retinopathy                         478
# Moderate bilateral impairment                              471
# Other/unspecified orbital and external disease             469
# Macular edema (not diabetic)                               451
# Primary angle-closure glaucoma                             435
# Lacrimal and orbit inflammation                            417
# Unqualified impairment in one eye, or unspecified          415
# Branch retinal artery occlusion                            394
# Other/unspecified glaucoma                                 392
# Malignant neoplasm                                         364
# Moderate imp. better eye, profound imp. lesser eye         359
# Central retinal vein occlusion                             342
# Occlusive retinal vascular disease                         313
# Profound bilateral imp., legal blindness                   297
# Disorders of the globe                                     228
# Neovascular glaucoma                                       219
# Endophthalmitis                                            204
# Congenital glaucoma                                        192
# Central retinal arterial occlusion                         187
# Ocular burns                                               155
# Unqualified impairment, both eyes                          121
# Visual pathway disorders                                   109
# Name: Response, Length: 93, dtype: int64
# ------------------
# Variable:  Age
# All Ages              13560
# 40-64 years           12969
# 65-84 years           11362
# 18-39 years           11100
# 0-17 years             8837
# 85 years and older     5878
# Name: Age, dtype: int64
# ------------------
# Variable:  Gender
# Total     22450
# Female    20759
# Male      20497
# Name: Gender, dtype: int64
# ------------------
# Variable:  RaceEthnicity
# All races    63706
# Name: RaceEthnicity, dtype: int64
# ------------------
# Variable:  RiskFactor
# All patients    63706
# Name: RiskFactor, dtype: int64
# ------------------
# Variable:  RiskFactorResponse
# Total    63706
# Name: RiskFactorResponse, dtype: int64
# ------------------
# Variable:  Data_Value_Unit
# %    63706
# Name: Data_Value_Unit, dtype: int64
# ------------------
# Variable:  Data_Value_Type
# Crude Prevalence    63706
# Name: Data_Value_Type, dtype: int64
# ------------------
# Variable:  Data_Value_Footnote_Symbol
# §    8
# Name: Data_Value_Footnote_Symbol, dtype: int64
# ------------------
# Variable:  Data_Value_Footnote
# Some estimates are not shown due to small sample size    8
# Name: Data_Value_Footnote, dtype: int64
# ------------------
# Variable:  GeoLocation
# (37.63864012300047, -120.99999953799971)     1638
# (44.6613195430005, -84.71439026999968)       1527
# (40.06021014100048, -82.40426005599966)      1484
# (39.766910452000445, -86.14996019399968)     1448
# (42.82700103200045, -75.54397042699964)      1400
# (44.56744942400047, -120.15503132599969)     1390
# (31.827240407000488, -99.42677020599967)     1389
# (47.52227862900048, -120.47001078999972)     1368
# (38.843840757000464, -106.13361092099967)    1347
# (40.48501028300046, -88.99771017799969)      1345
# (37.54268067400045, -78.45789046299967)      1328
# (28.932040377000476, -81.92896053899966)     1324
# (34.865970280000454, -111.76381127699972)    1308
# (35.466220975000454, -79.15925046299964)     1297
# (38.635790776000476, -92.56630005299968)     1295
# (39.493240390000494, -117.07184056399967)    1256
# (35.47203135600046, -97.52107021399968)      1255
# (32.83968109300048, -83.62758034599966)      1249
# (21.304850435000446, -157.85774940299973)    1243
# (40.13057004800049, -74.27369128799967)      1237
# (43.682630005000476, -114.3637300419997)     1232
# (38.34774030000045, -98.20078122699965)      1219
# (38.66551020200046, -80.71264013499967)      1217
# (34.52088095200048, -106.24058098499967)     1213
# (32.84057112200048, -86.63186076199969)      1208
# (47.06652897200047, -109.42442064499971)     1203
# (44.39319117400049, -89.81637074199966)      1198
# (42.27687047000046, -72.08269067499964)      1195
# (33.998821303000454, -81.04537120699968)     1195
# (46.35564873600049, -94.79420050299967)      1191
# (31.31266064400046, -92.44568007099969)      1190
# (32.745510099000455, -89.53803082499968)     1188
# (42.46940091300047, -93.81649055599968)      1182
# (35.68094058000048, -85.77449091399967)      1174
# (41.6410409880005, -99.36572062299967)       1165
# (39.29058096400047, -76.60926011099963)      1155
# (37.645970271000465, -84.77497104799966)     1141
# (40.79373015200048, -77.86070029399963)      1137
# (41.56266102000046, -72.64984095199964)      1128
# (39.360700171000474, -111.58713063499971)    1105
# (43.62538123900049, -72.51764079099962)      1087
# (43.23554134300048, -108.10983035299967)     1079
# (43.65595011300047, -71.50036091999965)      1064
# (44.353130053000484, -100.3735306369997)     1063
# (64.84507995700051, -147.72205903599973)     1044
# (34.74865012400045, -92.27449074299966)      1029
# (41.70828019300046, -71.52247031399963)      1021
# (39.008830667000495, -75.57774116799965)     1004
# (45.254228894000505, -68.98503133599962)      941
# (47.47531977900047, -100.11842104899966)      940
# (38.89037138500049, -77.03196112699965)       645
# (18.220833, -66.590149)                       223
# (13.444304, 144.793731)                       118
# (18.335765, -64.896335)                         8
# (11.3246908, 166.84174239999993)                8
# Name: GeoLocation, dtype: int64
# ------------------
# Variable:  TopicID
# TDX     60849
# TUTL     2857
# Name: TopicID, dtype: int64
# ------------------
# Variable:  CategoryID
# CDXC4     6138
# CDXC7     5635
# CDXC5     5583
# CDXC6     5504
# CDXC13    5447
# CDXC14    4802
# CDXC2     3907
# CDXC12    3776
# CDXC3     3573
# CDXC16    3136
# CDXC8     3018
# CUTLEX    2857
# CDXC9     2558
# CDXC10    2271
# CDXC15    2050
# CDXC11    1761
# CDXC17     895
# CDXC1      795
# Name: CategoryID, dtype: int64
# ------------------
# Variable:  QuestionID
# QDXC4     6138
# QDXC7     5635
# QDXC5     5583
# QDXC6     5504
# QDXC13    5447
# QDXC14    4802
# QDXC2     3907
# QDXC12    3776
# QDXC3     3573
# QDXC16    3136
# QDXC8     3018
# QUTLEX    2857
# QDXC9     2558
# QDXC10    2271
# QDXC15    2050
# QDXC11    1761
# QDXC17     895
# QDXC1      795
# Name: QuestionID, dtype: int64
# ------------------
# Variable:  ResponseID
# R14_4      1723
# R7_ALL      970
# R7_1        967
# REXOPT      963
# REXANY      963
# R7_3        961
# R7_2        959
# R7_4        956
# R6_ALL      941
# REXPHS      931
# R5_ALL      925
# R14_ALL     922
# R6_1        921
# R14_5       912
# R13_ALL     910
# R4_ALL      897
# R17_ALL     895
# R5_4        891
# R4_10       886
# R16_ALL     877
# R9_ALL      875
# R13_3       867
# R6_5        866
# R3_ALL      864
# R9_1        863
# R13_2       857
# R16_3       857
# R12_ALL     857
# R15_ALL     843
# R15_2       843
#            ...
# R8_3        624
# R10_3       613
# R5_1        579
# R2_2        573
# R12_2       542
# R3_4        520
# R5_3        502
# R4_3        482
# R2_3        478
# R8_5        471
# R14_2       469
# R4_7        451
# R5_5        435
# R13_6       417
# R8_2        415
# R4_5        394
# R5_9        392
# R15_1       364
# R8_4        359
# R4_2        342
# R4_1        313
# R8_6        297
# R14_6       228
# R5_8        219
# R13_7       204
# R5_7        192
# R4_4        187
# R10_2       155
# R8_1        121
# R11_2       109
# Name: ResponseID, Length: 93, dtype: int64
# ------------------
# Variable:  AgeID
# AGEALL       13560
# AGE4064      12969
# AGE6584      11362
# AGE1839      11100
# AGE017        8837
# AGE85PLUS     5878
# Name: AgeID, dtype: int64
# ------------------
# Variable:  GenderID
# GALL    22450
# GF      20759
# GM      20497
# Name: GenderID, dtype: int64
# ------------------
# Variable:  RaceEthnicityID
# ALLRACE    63706
# Name: RaceEthnicityID, dtype: int64
# ------------------
# Variable:  RiskFactorID
# RFALL    63706
# Name: RiskFactorID, dtype: int64
# ------------------
# Variable:  RiskFactorResponseID
# RFTOT    63706
# Name: RiskFactorResponseID, dtype: int64

# %% [markdown]
# Need to get rid of ID columns that don't provide any useful information and columns with no variance next
